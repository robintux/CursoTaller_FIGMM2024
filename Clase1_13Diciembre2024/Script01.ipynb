# %%
# Declaracion de variables
x = 12
y = 0.36
z = "Primera Clase"
w = '13/12/2024'
b1 = True
b2 = False
c = 12 + 9j

# Modulo matematico
import math

# Funcion que calcula las raices de una ecuacion
def equationroots( a, b, c):
    # Calculo del discriminante
    dis = b * b - 4 * a * c
    sqrt_val = math.sqrt(abs(dis))
    # Verificando las condiciones sobre el discriminante
    if dis > 0:
        print("Raices reales y diferentes")
        print("X1 = " , (-b + sqrt_val)/(2 * a))
        print("X2 = " ,(-b - sqrt_val)/(2 * a))
    elif dis == 0:
        print("Raices reales e iguales")
        print(-b / (2 * a))
    # when discriminant is less than 0
    else:
        print("Raices complejas")
        print(- b / (2 * a), "+ i", sqrt_val / (2 * a))
        print(- b / (2 * a), "- i", sqrt_val / (2 * a))

# Prueba1
a = 1
b = 10
c = -24

# Si a es igual a cero => No es una ecuacion cuadratica
if a == 0:
        print("El coeficiente cuadratico no debe ser cero")

else:
    equationroots(a, b, c)

# %% [markdown]
# # Primeros pasos con Python
# ## Declaracion de variables
# Algunos comentarios
# * PAra definir variables en python lo hacemos mediantes : `nombre_variable = valor`
# * Recordar siempre que los nombres de las variables deben estar asociados al uso que le vamos a dar.
# * Los nombres de variables no deben de contener espacios en blanco, caracteres tildados y "/" o "\"

# %%
# Operaciones aritmeticas
x1 = ( (x+y) * (y/0.81) )**(0.39)
x1
# Out:
# 1.9432828661522425

# %%
# Division entera
num = 2024
den = 1982
q = num // den
r = num % den

# %%
q
# Out:
# 1

# %%
r
# Out:
# 42

# %%
d = (c ** 3)/(c+ 3.5j)
d
# Out:
# (84.03497085761865+175.71357202331387j)

# %%
# Variables booleanas : AND OR NOT
b3 = b1 and b2
b4 = b3 or b1
b5 = not b4

# %%
b3
# Out:
# False

# %%
b4
# Out:
# True

# %%
b5
# Out:
# False

# %%
b6 = (b1 and b5) or (b3 and (not b5))
b6
# Out:
# False

# %%
# Operadores de comparacion
x1 = x <= y**(3.56)
x2 = x == x1
x3 = y**(-0.71) > 19.5

# %%
x3
# Out:
# False

# %%
# Python es un lenguaje de tipado de dinamico
x3 = (2024)**(-14.5)
x3
# Out:
# 1.1480151822972486e-48

# %%
# Carga del modulo matematico
import math as m

# %%
# Carguemos el modulo pyomo
import pyomo as opt

# %%
# Carguemos el modulo sympy
import sympy

# %% [markdown]
# ## Documentacion del modulo matematico

# %%
# Funcion help
help(m)

# %%
x = 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-21-bfdf2b0f658a> in <cell line: 1>()
# ----> 1 x = 1/0
#
# ZeroDivisionError: division by zero

# %%
x
# Out:
# 12

# %%
# Constante del modulo math
m.inf > x
# Out:
# True

# %%
# Listemos los elementos que componen al modulo math (alias m)
dir(m)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
# Aprendamos a utilizar la funcion hypot
help(m.hypot)

# %%
# Aprendamos a utilizar la funcion exp
help(m.exp)
# Out:
# Help on built-in function exp in module math:
#
# exp(x, /)
#     Return e raised to the power of x.

# %%
#
m.exp(m.inf)
# Out:
# inf

# %%
#
1/(m.exp(m.inf**(-10**6)))
# Out:
# 1.0

# %%
# MOdulo random
import random as rnd

# %%
# Documentacion del modulo random (alias rnd)
help(rnd)

# %%
# Listemos los elementos que componen al modulo random
dir(rnd)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
# # Elementos de interes del modulo random
# 'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate'

# %%
# Documentacion de la funcion randint
help(rnd.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
# NUmero aleatorio en [0,20]
rnd.randint(0,20)
# Out:
# 20

# %%
# Documentacion del modulo sympy
help(sympy)

# %%
x + x
# Out:
# 24
