# %% [markdown]
# # Variables de tipo cadena de caracter

# %%
x = "Primera Clase del curso"
y = "Viernes 13 de diciembre del 2024"

# %%
z = """Hasta ahora recuerdo aquella tarde en que al pasar por el malecón divisé en un
pequeño basural un objeto brillante. Con una curiosidad muy explicable en mi temperamente
de coleccionista, me agaché y después de recogerlo lo froté contra la manga de mi saco. Así
pude observar que se trataba de una menuda insignia de plata, atravesada por unos signos
que en ese momento me parecieron incomprensibles. Me la eché al bolsillo y, sin darle
mayor importancia al asunto, regresé a mi casa. No puedo precisar cuánto tiempo estuvo
guardada en aquel traje que usaba poco. Sólo recuerdo que en una oportunidad lo mandé a
lavar y, con gran sorpresa mía, cuando el dependiente me lo devolvió limpio, me entregó
una cajita, diciéndome: "Esto debe ser suyo, pues lo he encontrado en su bolsillo".
Era, naturalmente, la insignia y este rescate inesperado me conmovió a tal extremo
que decidí usarla.
Aquí empieza realmente el encadenamiento de sucesos extraños que me
acontecieron. Lo primero fue un incidenbte que tuve en una librería de viejo. Me hallaba
repasando añejas encuadernaciones cuando el patrón, que desde hacía rato e observaba
desde el ángulo más oscuro de su librería, se me acercó y, con un tono de complicidad,
entre guiños y muecas convencionales, me dijo: "Aquí tenemos libros de Feifer". Yo lo quedé
mirando intrigado porque no había preguntado por dicho autor, el cual, por lo demás, aunque
mis conocimientos de literatura no son muy amplios, me era enteramente desconocido. Y
acto seguido añadió: "Feifer estuvo en Pilsen". Como yo no saliera de mi estupor, el librero
terminó con un tono de revelación, de confidencia definitiva: "Debe usted saber que lo
mataron. Sí, lo mataron de un bastonazo en la estación de Praga". Y dicho esto se retiró
hacia el ángulo de donde había surgido y permaneció en el más profundo silencio. Yo seguí
revisando algunos volúmenes maquinalmente pero mi pensamiento se hallaba preocupado
en las palabras enigmáticas del librero. Después de comprar un libro de mecánica salí,
desconcertado, del negocio. """

# %%
# Las variables de tipo cadena de caracter tienen una naturaleza vectorial
# En Python, los indices inician en cero

# %%
# Primera componente de x
x[0]
# Out:
# 'P'

# %%
# Mostremos x
x
# Out:
# 'Primera Clase del curso'

# %%
# Octava componente con el indice 7
x[7]
# Out:
# ' '

# %%
# Ultimo elemento : indice -1
x[-1]
# Out:
# 'o'

# %%
# Antepenultimo elemento de x
x[-3]
# Out:
# 'r'

# %%
# PRimeros cinco caracteres de x
x[0:4+1]
# Out:
# 'Prime'

# %%
# Primeros 10 caracteres de z
z[0:9+1]
# Out:
# 'Hasta ahor'

# %%
# 20 ultimos elementos de z
z[-20:]
# Out:
# 'rtado, del negocio. '

# %%
# Almacenemos los ultimo 3 caracteres de y en la variable t
t = y[-3:]
t
# Out:
# '024'

# %%
# NUmero de elementos de una variable de tipo cadena de caracter :
Num_elementos_x = len(x)
Num_elementos_x
# Out:
# 23

# %%
# Treintaavo elemento de x
x[29]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-8c939b2b34e5> in <cell line: 2>()
#       1 # Treintaavo elemento de x
# ----> 2 x[29]
#
# IndexError: string index out of range

# %%
# Numero de elementos de la variable z
Num_elementos_z = len(z)
Num_elementos_z
# Out:
# 2042

# %%
# Operacion de concatenacion
dos_veces_z = z +z
len(dos_veces_z)
# Out:
# 4084

# %%
w = "12345" + "xxxxx"
w
# Out:
# '12345xxxxx'

# %%
# Operacion de repeticion
v = 3 * w
v
# Out:
# '12345xxxxx12345xxxxx12345xxxxx'

# %%
j = ( 2 * w ) + (v * 5)
j
# Out:
# '12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx12345xxxxx'

# %%
# modulo string
import string

# %%
# Documentacion del modulo string
help(string)

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
cadena_caracter = string.punctuation

# %%
# primer signo de puntuacion
cadena_caracter[0]
# Out:
# '!'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
# Metodos que se puede aplicar a una variable de tipo cadena de caracter
dir(x)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
# Documentacion del metodo replace
help(x.replace)
# Out:
# Help on built-in function replace:
#
# replace(old, new, count=-1, /) method of builtins.str instance
#     Return a copy with all occurrences of substring old replaced by new.
#
#       count
#         Maximum number of occurrences to replace.
#         -1 (the default value) means replace all occurrences.
#
#     If the optional argument count is given, only the first count occurrences are
#     replaced.

# %%
# Definamos una variable de tipo cadena de caracter
x1 = "Esto es un mensaje de suma importancia, asi que debe ser cifrado"
x1
# Out:
# 'Esto es un mensaje de suma importancia, asi que debe ser cifrado'

# %%
x1.replace("o", "0")
# Out:
# 'Est0 es un mensaje de suma imp0rtancia, asi que debe ser cifrad0'

# %%
x1
# Out:
# 'Esto es un mensaje de suma importancia, asi que debe ser cifrado'

# %%
x1.replace("o", "0").replace("i", "1").replace("e", "3").replace("a","4").replace(" ", "_")
# Out:
# 'Est0_3s_un_m3ns4j3_d3_sum4_1mp0rt4nc14,_4s1_qu3_d3b3_s3r_c1fr4d0'

# %%
x1
# Out:
# 'Esto es un mensaje de suma importancia, asi que debe ser cifrado'
