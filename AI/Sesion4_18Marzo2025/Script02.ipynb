# %%
# Problema 1 : Representar el lenguaje humano de una manera numerica
  # Representacion discreta
    # Bag-of-Words
    # TF-IDF
  # Representacion distribuida : Word Embeddings
    # word2vec
    # GloVe
    # FastTest

# %%
# Formular problemas especificos del Procesamiento del Lenguaje Natural
  # Clasificacion de Texto
  # Extraccion de informacion
  # Traduccion automatica
  # Resumen de Texto
  # Analisis de sentimiento

# %% [markdown]
# # word2vec
#   * Continuous Bag of words
#   * Skip-gram

# %% [markdown]
# # GENSIM

# %%
import numpy as np
import scipy
print("numpy : ", np.__version__)
print("scipy : ", scipy.__version__)
# Out:
# numpy :  2.0.2
# scipy :  1.14.1

# %%
# INstalemos gensim
# !pip install numpy==1.26.4
# !pip install scipy==1.13
# !pip install --upgrade gensim==4.3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 72.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 46.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 2.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 74.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 4.9 MB/s eta 0:00:00
# ...

# %%
import gensim

# %%
gensim.__version__
# Out:
# '4.3.0'

# %%
import gensim.downloader as api

# %%
# Modelo de google
model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
# !python -m gensim.downloader --info word2vec-google-news-300
# Out:
# {
#     "num_records": 3000000,
#     "file_size": 1743563840,
#     "base_dataset": "Google News (about 100 billion words)",
#     "reader_code": "https://github.com/RaRe-Technologies/gensim-data/releases/download/word2vec-google-news-300/__init__.py",
#     "license": "not found",
#     "parameters": {
#         "dimension": 300
#     },
#     "description": "Pre-trained vectors trained on a part of the Google News dataset (about 100 billion words). The model contains 300-dimensional vectors for 3 million words and phrases. The phrases were obtained using a simple data-driven approach described in 'Distributed Representations of Words and Phrases and their Compositionality' (https://code.google.com/archive/p/word2vec/).",
#     "read_more": [
#         "https://code.google.com/archive/p/word2vec/",
#         "https://arxiv.org/abs/1301.3781",
#         "https://arxiv.org/abs/1310.4546",
# ...

# %%
model.similarity("king","queen")
# Out:
# 0.6510957

# %%
model.similarity("king", "man")
# Out:
# 0.22942673

# %%
model.similarity("king", "potato")
# Out:
# 0.09978465

# %%
model.similarity("king", "king")
# Out:
# 1.0

# %%
model.most_similar(["king","queen"], topn = 10)

# [('monarch', 0.7042067050933838),
#  ('kings', 0.6780861616134644),
#  ('princess', 0.6731551885604858),
#  ('queens', 0.6679497957229614),
#  ('prince', 0.6435247659683228),
#  ('royal', 0.5985592603683472),
#  ('princes', 0.5942344665527344),
#  ('crown_prince', 0.5906674265861511),
#  ('NYC_anglophiles_aflutter', 0.5811060070991516),
#  ('Queen_Consort', 0.5735103487968445)]
# Out:
# [('monarch', 0.7042067050933838),
#  ('kings', 0.6780861616134644),
#  ('princess', 0.6731551885604858),
#  ('queens', 0.6679497957229614),
#  ('prince', 0.6435247659683228),
#  ('royal', 0.5985592603683472),
#  ('princes', 0.5942344665527344),
#  ('crown_prince', 0.5906674265861511),
#  ('NYC_anglophiles_aflutter', 0.5811060070991516),
#  ('Queen_Consort', 0.5735103487968445)]

# %%
model.doesnt_match(["summer", "spring", "fall","water"])
# Out:
# 'water'
